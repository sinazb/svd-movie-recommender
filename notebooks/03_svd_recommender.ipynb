# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import TruncatedSVD

# %%
ratings = pd.read_csv(
    "../data/ml-100k/u.data",
    sep="\t",
    names=["user_id", "movie_id", "rating", "timestamp"]
)

user_movie = ratings.pivot(
    index="user_id",
    columns="movie_id",
    values="rating"
)

# Mean centering
user_means = user_movie.mean(axis=1)
user_movie_centered = user_movie.sub(user_means, axis=0)

# Fill NaNs with 0
matrix = user_movie_centered.fillna(0).values

# %%
k = 20

# %%
svd = TruncatedSVD(n_components=k, random_state=42)
U = svd.fit_transform(matrix)
Sigma = svd.singular_values_
VT = svd.components_

# %%
print(U.shape)      # (users, k)
print(Sigma.shape) # (k,)
print(VT.shape)    # (k, movies)
# Out:
# (943, 20)
# (20,)
# (20, 1682)

# %%
Sigma_matrix = np.diag(Sigma)
reconstructed = np.dot(np.dot(U, Sigma_matrix), VT)

# %%
reconstructed += user_means.values.reshape(-1, 1)

# %%
reconstructed_df = pd.DataFrame(
    reconstructed,
    index=user_movie.index,
    columns=user_movie.columns
)

reconstructed_df.head()
# Out:
# movie_id       1         2         3          4          5         6     \
# user_id
# 1         60.806546 -5.408948 -6.002044   5.934714 -16.008613  6.898390
# 2          2.756193  3.354869 -1.245336   4.315434   2.486831  5.218668
# 3          0.641090  1.581151 -0.543322   5.652423   2.917747  3.109414
# 4          9.315613  4.412405  4.789807   3.073277   2.585963  4.467742
# 5         41.732761  1.505962 -8.421217  12.874197  -3.965090  4.085836
#
# movie_id       7          8          9          10    ...      1673      1674  \
# user_id                                               ...
# 1         58.582252  21.155579  55.280187  13.087130  ...  3.610509  3.598407
# 2          9.993978  12.164082  13.308380   1.957832  ...  3.558561  3.716423
# 3          1.322581   2.573878   4.824746   2.524461  ...  2.773451  2.799435
# 4          7.314908   5.626426   5.698263   4.980957  ...  4.365363  4.334576
# 5         47.768134  18.275460  -3.068532   8.421112  ...  2.976195  2.906664
#
# movie_id      1675      1676      1677      1678      1679      1680  \
# user_id
# 1         3.624802  3.656386  3.517752  2.884160  3.568709  3.226434
# 2         3.649097  3.517209  3.656629  3.648479  3.706173  3.677326
# 3         2.759447  2.679222  2.796683  3.120161  2.814844  2.967502
# 4         4.323666  4.302621  4.327335  4.039300  4.316494  4.177897
# 5         2.803447  2.649225  2.944176  3.051174  2.884416  2.967795
#
# movie_id      1681      1682
# user_id
# 1         3.635476  3.162724
# 2         3.708244  3.748310
# 3         2.793966  2.785063
# 4         4.335070  4.299425
# 5         2.878416  2.728988
#
# [5 rows x 1682 columns]

# %%
movies = pd.read_csv(
    "../data/ml-100k/u.item",
    sep="|",
    encoding="latin-1",
    header=None
)

movies = movies[[0, 1]]
movies.columns = ["movie_id", "title"]

# %%
def recommend_movies(user_id, n=5):
    user_ratings = user_movie.loc[user_id]
    unseen_movies = user_ratings[user_ratings.isna()].index
    
    predictions = reconstructed_df.loc[user_id, unseen_movies]
    top_movies = predictions.sort_values(ascending=False).head(n)
    
    return movies[movies["movie_id"].isin(top_movies.index)]

# %%
recommend_movies(user_id=10, n=5)
# Out:
#      movie_id                           title
# 78         79            Fugitive, The (1993)
# 88         89             Blade Runner (1982)
# 186       187  Godfather: Part II, The (1974)
# 317       318         Schindler's List (1993)
# 426       427    To Kill a Mockingbird (1962)
